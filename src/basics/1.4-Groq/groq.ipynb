# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

model = ChatGroq(
    model="qwen/qwen3.6-27b"
)
messages = [
    ("system", "You are a helpful translator. Translate the user sentence to hindi."),
    ("human", "I love programming."),
]
response = model.invoke(messages)

# %%
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:**
#    - User sentence: "I love programming."
#    - Target language: Hindi
#    - Task: Translate the sentence accurately and naturally.
#
# 2.  **Identify Key Components:**
#    - Subject: I (मैं)
#    - Verb: love (पसंद करता/करती हूँ / प्रेम करता/करती हूँ)
#    - Object: programming (प्रोग्रामिंग / कोडिंग / प्रोग्राम बनाना)
#
# 3.  **Determine Gender/Context:**
#    - Hindi verbs/adjectives change based on the speaker's gender.
#    - Since the user's gender isn't specified, I should provide both masculine and feminine forms, or use a neutral/context-appropriate form.
#    - Common practice: Provide masculine default, but note feminine, or give both.
#    - "मैं प्रोग्रामिंग पसंद करता हूँ।" (masculine)
#    - "मैं प्रोग्रामिंग पसंद करती हूँ।" (feminine)
#    - Alternatively, use "मुझे प्रोग्रामिंग बहुत पसंद है।" which is gender-neutral and more natural in Hindi.
#
# 4.  **Select Best Translation:**
#    - "मुझे प्रोग्रामिंग बहुत पसंद है।" (I really like love programming.)
#    - This is idiomatic, natural, and gender-neutral.
#    - "प्रोग्रामिंग" is commonly used in Hindi for programming. "कोडिंग" is also used but "प्रोग्रामिंग" is more direct.
#    - Add "बहुत" for "love" to convey stronger affection, though "पसंद है" alone can mean "like". "बहुत पसंद है" = love/like very much.
#
# 5.  **Formulate Output:**
#    - Provide the translation clearly.
#    - Optionally note gender variations if needed, but keep it concise.
#    - Final: "मुझे प्रोग्रामिंग बहुत पसंद है।" (Gender-neutral and natural)
#
# 6.  **Self-Correction/Verification:**
#    - Check accuracy: "I love programming." -> "मुझे प्रोग्रामिंग बहुत पसंद है।" ✓
#    - Check grammar: Correct Hindi structure (मुझे + object + बहुत पसंद है) ✓
#    - Check tone: Matches original ✓
#    - Could also say "मैं प्रोग्रामिंग से बहुत प्यार करता/करती हूँ।" but that's less common/idiomatic. "पसंद है" is standard.
#    - I'll stick with the natural, gender-neutral version.
#
#    Output matches the required format. Provide just the translation as requested, maybe with a brief note if needed, but keep it direct.✅
# </think>
#
# मुझे प्रोग्रामिंग बहुत पसंद है।
